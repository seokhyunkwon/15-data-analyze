# %%
import pandas as pd
dic = {'a':1, 'b':2, 'c':3}
sr = pd.Series(dic)
print(type(sr))
print(sr)
# Out:
# <class 'pandas.Series'>
# a    1
# b    2
# c    3
# dtype: int64

# %%
lis = ['2019-01-02', 3.14, 'ABC', 100, True]
sr = pd.Series(lis)
print(sr)
# Out:
# 0    2019-01-02
# 1          3.14
# 2           ABC
# 3           100
# 4          True
# dtype: object

# %%
idx = sr.index
print(idx)
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
val = sr.values
print(val)
# Out:
# ['2019-01-02' 3.14 'ABC' 100 True]

# %%
print(sr.dtype)
# Out:
# object

# %%
print(len(sr))
# Out:
# 5

# %%
# 형태
print(sr.shape)
# Out:
# (5,)

# %%
# 차원
print(sr.ndim)
# Out:
# 1

# %%
tup = ('영인', '2010-05-10', '여', True)
sr = pd.Series(tup, index=['이름', '생년월일', '성별', '학생여부'])
print(sr)
# Out:
# 이름              영인
# 생년월일    2010-05-10
# 성별               여
# 학생여부          True
# dtype: object

# %%
print(sr.iloc[0])
print(sr['이름'])
print(sr[0])
# Out:
# 영인
# 영인
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Win11Pro\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\base.py:3641, in Index.get_loc(self, key)
#    3640 try:
# -> 3641     return self._engine.get_loc(casted_key)
#    3642 except KeyError as err:
#
# File pandas/_libs/index.pyx:168, in pandas._libs.index.IndexEngine.get_loc()
# --> 168 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
# --> 176 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/index.pyx:583, in pandas._libs.index.StringObjectEngine._check_type()
# --> 583 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyError: 0
#
# ...

# %%
print(sr[['생년월일', '성별']])
print('\n')
print(sr.iloc[[1, 2]])
# Out:
# 생년월일    2010-05-10
# 성별               여
# dtype: object
#
#
# 생년월일    2010-05-10
# 성별               여
# dtype: object

# %%
print(sr.iloc[1:2])
print('\n')
print(sr['생년월일':'성별'])
# Out:
# 생년월일    2010-05-10
# dtype: object
#
#
# 생년월일    2010-05-10
# 성별               여
# dtype: object

# %%
pd.Series()
# Out:
# Series([], dtype: object)

# %%
pd.Series(5)
# Out:
# 0    5
# dtype: int64

# %%
pd.Series(5, index=['a', 'b', 'c'])
# Out:
# a    5
# b    5
# c    5
# dtype: int64
